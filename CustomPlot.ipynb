# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

data_frame = pd.DataFrame(columns=['m', 'd', 'MAE', 'MSE', 'MRE'], 
                            data=[ [3,2,53.84,6109.42,0.27], 
                                [4,2,60.40,7523.96,0.23],
                                [4,3,91.39,14616.13,0.56],
                                [5,3,78.21,11262.46,0.47],
                                [5,4,95.33,14490.87,0.81]])

# %%
figure1, ax1 = plt.subplots(2, figsize=(15, 15))

sns.boxplot(x='m', y='MRE', data=data_frame, ax=ax1[0], palette="Set3")
sns.boxplot(x='d', y='MRE', data=data_frame, ax=ax1[1], palette="Set3")
# Out:
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_16521/2505068275.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='m', y='MRE', data=data_frame, ax=ax1[0], palette="Set3")
# /var/folders/k2/frn908kd4_q13s9qm8hj9zcw0000gn/T/ipykernel_16521/2505068275.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='d', y='MRE', data=data_frame, ax=ax1[1], palette="Set3")
# <Axes: xlabel='d', ylabel='MRE'>
